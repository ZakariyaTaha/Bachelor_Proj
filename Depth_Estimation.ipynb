# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Bachelor_Proj
# Out:
# /content/drive/MyDrive/Bachelor_Proj

# %%
# !ls
# Out:
# apply.py	   dataloader		   image_179_stage_1.png  pil_0.png
# app.py		   Depth_Estimation.ipynb  image_179_stage_2.png  pil_1.png
# checkpoint	   fig_0.png		   LICENSE		  pil_2.png
# colored_pil_0.png  fig_1.png		   main.py		  README.md
# create_dataset.sh  fig_2.png		   models		  results
# data		   finetune.py		   my_finetune.py	  test_im
# Data_3		   image_179_stage_0.png   Our_Dataset		  utils

# %%
import os
import PIL
import cv2
import numpy as np

# %%
import argparse
import os
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.optim as optim
import torch.utils.data
import torch.nn.functional as F
import time
from dataloader import KITTILoader as DA
import utils.logger as logger
import torch.backends.cudnn as cudnn
import pdb
import models.anynet

# %% [markdown]
# ### Change file names + Change disparity sizes

# %%
for i, image_name in enumerate(os.listdir('data/validation/disp_occ_0')):
  image = PIL.Image.open("data/validation/disp_occ_0/" + image_name)
  new_image = image.resize((3840, 1920))
  new_image.save('data/validation/disp_occ_0/' + image_name)

# %%
#print(os.listdir('/content/drive/MyDrive/Bachelor_Proj/data/training/image_3'))
for i, file in enumerate(os.listdir('data/training/disp_occ_0')):
  os.rename(r'data/training/disp_occ_0/' + file ,r'data/training/disp_occ_0/image_'+ str(i)+'.png')

# %%
# ?cv2.resize

# %%
print(os.path.isfile('checkpoint/sceneflow/sceneflow.tar'))
# Out:
# False

# %%
image = PIL.Image.open("disp.png")
width, height = image.size
print('width: ', width, 'height ', height)

img = cv2.imread("disp.png")
wid = img.shape[1]
hgt = img.shape[0]
  
# displaying the dimensions
print(str(wid) + "x" + str(hgt))
# Out:
# width:  1241 height  376
# 1241x376

# %%
image = PIL.Image.open("/content/drive/MyDrive/Bachelor_Proj/Our_Dataset/validation/disp_occ_0/image_179.png")
## print(np.all(np.asarray(image)[:,:,0]==np.asarray(image)[:,:,2]))
print((np.asarray(image)[:,:,0]).max())
# Out:
# 255

# %%
image = PIL.Image.open("/content/drive/MyDrive/Bachelor_Proj/000000_10.png")
## print(np.all(np.asarray(image)[:,:,0]==np.asarray(image)[:,:,2]))
print(np.asarray(image).max())
# Out:
# 16406

# %%
image = PIL.Image.open("/content/drive/MyDrive/Bachelor_Proj/left0000.jpg")
## print(np.all(np.asarray(image)[:,:,0]==np.asarray(image)[:,:,2]))
print((np.asarray(image)[:,:,0]).max())
# Out:
# 255

# %% [markdown]
# #### Tests on DataSet

# %%
image = PIL.Image.open("data_2/validation/image_2/image_1.png")
width, height = image.size
print('width: ', width, 'height ', height)

img = cv2.imread("data_2/validation/image_2/image_1.png")
wid = img.shape[1]
hgt = img.shape[0]
  
# displaying the dimensions
print(str(wid) + "x" + str(hgt))
# Out:
# width:  3840 height  1920
# 3840x1920

# %%
image = PIL.Image.open('data_2/training/disp_occ_0/image.png')
new_image = image.resize((3840, 1920))
new_image.save('data_2/training/disp_occ_0/image_t.png')

image = PIL.Image.open('data_2/validation/disp_occ_0/image_1.png')
new_image = image.resize((3840, 1920))
new_image.save('data_2/validation/disp_occ_0/image_1_t.png')

# %%
print(os.getcwd())
# Out:
# /content/drive/MyDrive/Bachelor_Proj

# %%
print('basename:    ', os.path.basename('data_2/validation/disp_occ_0/image_1.png'))
# Out:
# basename:     image_1.png

# %%
image = PIL.Image.open('./Our_Dataset/training/image_2/image_179.png')
print(np.asarray(image)[1000][1000])
# Out:
# [158 124 106]

# %%
imgt = cv2.imread("Data_4/training/image_2/image.png")
imgt.shape
# Out:
# (1920, 3840, 3)

# %% [markdown]
# ### To remember
#
# They crop randomly

# %% [markdown]
# ### Changes
#
# Workers = 0 done <br>
# printed left size <br>
# printed train and val sizes <br>
# Resize <br>

# %% [markdown]
# #### Finetune

# %%
# !python finetune.py --maxdisp 192 --pretrained checkpoint/sceneflow/sceneflow.tar --datapath data --datatype other

# %% [markdown]
# ## Apply on image

# %%
# !ls
# Out:
# 000000_10.png	   Data_3		   image_179_stage_2.png  pil_2.png
# apply.py	   dataloader		   left0000.jpg		  README.md
# app.py		   Depth_Estimation.ipynb  LICENSE		  results
# checkpoint	   fig_0.png		   main.py		  results_colab
# colored_pil_0.png  fig_1.png		   models		  test_im
# create_dataset.sh  fig_2.png		   my_finetune.py	  utils
# data		   finetune.py		   Our_Dataset
# data_2		   image_179_stage_0.png   pil_0.png
# Data_2		   image_179_stage_1.png   pil_1.png

# %%
# !python my_finetune.py --maxdisp 192 --datapath data_2/ --save_path results_colab/khkbou/apptesllkmt --datatype other --pretrained checkpoint/kitti2015_ck/checkpoint.tar
# Out:
# tr left 1
# tr right 1
# tr disp 1
# te left 1
# te right 1
# te disp 1
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [2021-06-08 14:45:29 my_finetune.py:89] INFO     channels_3d: 4
# [2021-06-08 14:45:29 my_finetune.py:89] INFO     datapath: data_2/
# [2021-06-08 14:45:29 my_finetune.py:89] INFO     datatype: other
# [2021-06-08 14:45:29 my_finetune.py:89] INFO     epochs: 300
# [2021-06-08 14:45:29 my_finetune.py:89] INFO     evaluate: False
# [2021-06-08 14:45:29 my_finetune.py:89] INFO     growth_rate: [4, 1, 1]
# ...

# %%
# !python app.py --maxdisp 192 --datapath Data_3/training/ --save_path results_colab/kitti2015/apptest --datatype 2015 --pretrained checkpoint/kitti2015_ck/checkpoint.tar

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# left size torch.Size([1, 3, 368, 1232])
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3328: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# ...

# %%
# !python my_finetune.py --maxdisp 192 --epochs 1000 --lr 5e-4 --max_disparity 192 --datapath Data_To_Use/ --pretrained checkpoint/sceneflow/sceneflow.tar --datatype other
# Out:
# Streaming output truncated to the last 5000 lines.
# [2021-06-14 14:08:36 my_finetune.py:189] INFO     Average train loss = Stage 0 = 6.21	Stage 1 = 10.59	Stage 2 = 18.28
# left size torch.Size([1, 3, 64, 1024])
# [2021-06-14 14:08:37 my_finetune.py:214] INFO     [0/1] Stage 0 = 0.6821(0.6821)	Stage 1 = 0.6434(0.6434)	Stage 2 = 0.6247(0.6247)
# [2021-06-14 14:08:37 my_finetune.py:217] INFO     Average test 3-Pixel Error = Stage 0=0.6821, Stage 1=0.6434, Stage 2=0.6247
# [2021-06-14 14:08:37 my_finetune.py:127] INFO     This is 168-th epoch
# left size torch.Size([1, 3, 64, 1024])
# [2021-06-14 14:08:37 my_finetune.py:189] INFO     Average train loss = Stage 0 = 6.26	Stage 1 = 10.62	Stage 2 = 17.88
# left size torch.Size([1, 3, 64, 1024])
# [2021-06-14 14:08:37 my_finetune.py:214] INFO     [0/1] Stage 0 = 0.6758(0.6758)	Stage 1 = 0.6361(0.6361)	Stage 2 = 0.6321(0.6321)
# ...

# %%
# !python apply.py --maxdisp 255 --datapath Data_To_Use/ --datatype other --pretrained results/finetune_anynet/checkpoint.tar
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# left size torch.Size([1, 3, 64, 1024])
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3328: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# ...

# %%
# !python app.py --maxdisp 255 --datapath Data_To_Use/ --datatype 2015 --pretrained checkpoint/kitti2015_ck/checkpoint.tar
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# left size torch.Size([1, 3, 368, 1232])
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3328: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# ...

# %%
# !python my_finetune.py --maxdisp 192 --epochs 1000 --lr 5e-4 --max_disparity 192 --datapath data_2/ --pretrained checkpoint/sceneflow/sceneflow.tar --datatype other
# Out:
# Streaming output truncated to the last 5000 lines.
# [2021-06-15 11:32:13 my_finetune.py:189] INFO     Average train loss = Stage 0 = 9.87	Stage 1 = 17.66	Stage 2 = 34.26
# left size torch.Size([1, 3, 480, 960])
# [2021-06-15 11:32:13 my_finetune.py:214] INFO     [0/1] Stage 0 = 0.7411(0.7411)	Stage 1 = 0.6276(0.6276)	Stage 2 = 0.6063(0.6063)
# [2021-06-15 11:32:13 my_finetune.py:217] INFO     Average test 3-Pixel Error = Stage 0=0.7411, Stage 1=0.6276, Stage 2=0.6063
# [2021-06-15 11:32:13 my_finetune.py:127] INFO     This is 168-th epoch
# left size torch.Size([1, 3, 480, 960])
# [2021-06-15 11:32:13 my_finetune.py:189] INFO     Average train loss = Stage 0 = 9.87	Stage 1 = 17.68	Stage 2 = 34.39
# left size torch.Size([1, 3, 480, 960])
# [2021-06-15 11:32:14 my_finetune.py:214] INFO     [0/1] Stage 0 = 0.7425(0.7425)	Stage 1 = 0.6261(0.6261)	Stage 2 = 0.6116(0.6116)
# ...

# %%
# !python app.py --maxdisp 255 --datapath data_2/ --datatype 2015 --pretrained checkpoint/kitti2015_ck/checkpoint.tar
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# left size torch.Size([1, 3, 368, 1232])
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3328: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# ...

# %%
# !python apply.py --maxdisp 255 --datapath data_2/ --datatype other --pretrained results/finetune_anynet/checkpoint.tar
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# left size torch.Size([1, 3, 480, 960])
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3328: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# ...
